# %%
a = 20
b = 23

# %%
a+b
# Out:
# 43

# %%
a-b
# Out:
# -3

# %%
a*b
# Out:
# 460

# %%
a/b
# Out:
# 0.8695652173913043

# %%
a//b
# Out:
# 0

# %%
c = 35
d =16

# %%
c/d
# Out:
# 2.1875

# %%
c//d #important
# Out:
# 2

# %%
2**2
# Out:
# 4

# %%
2**3
# Out:
# 8

# %%
c**d
# Out:
# 5070942774902496337890625

# %%
c%d
# Out:
# 3

# %%
d == c
# Out:
# False

# %%
c == d
# Out:
# True

# %%
c != d
# Out:
# False

# %%
c >= d
# Out:
# True

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
a = 20

# %%
a += 5

# %%
a
# Out:
# 25

# %%
a-=5

# %%
a
# Out:
# 20

# %%
11//2
# Out:
# 5

# %%
a = 11

# %%
a //= 2

# %%
a
# Out:
# 5
