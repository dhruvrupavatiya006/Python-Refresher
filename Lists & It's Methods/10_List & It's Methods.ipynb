# %%
#LISTS : orderd mutable collections of elements

# %%
l = ['Dhruv', 'Meet', 'Mihir', 'Sourav', 'Krunal']

# %%
l
# Out:
# ['Dhruv', 'Meet', 'Mihir', 'Sourav', 'Krunal']

# %%
#UNLIKE String we will not get another LIST after applying list methods in most of the cases.

# %%
l = [2, 3, 4, 5, 6]

# %%
l
# Out:
# [2, 3, 4, 5, 6]

# %%
l.append(9)

# %%
l
# Out:
# [2, 3, 4, 5, 6, 9]

# %%
l2 = [4, 5]

# %%
l.extend(l2)

# %%
l
# Out:
# [2, 3, 4, 5, 6, 9, 4, 5]

# %%
l.insert(1, 300) #Insert 300 at index 1

# %%
l
# Out:
# [2, 300, 300, 9]

# %%
num = l.pop(3)

# %%
num
# Out:
# 9

# %%
l
# Out:
# [2, 300, 300]

# %%
l.index(300)
# Out:
# 1

# %%
l.index(2)
# Out:
# 0

# %%
l.remove(2)

# %%
l
# Out:
# [300, 300]

# %%
l.count(4)
# Out:
# 0

# %%
l.count(2)
# Out:
# 0

# %%
newl = [2, 3, 5, 4, 7, 8, 67]

# %%
sorted(newl) #RETURNS NEW LIST WHICH IS SORTED.
# Out:
# [2, 3, 4, 5, 7, 8, 67]

# %%
newl.sort() #SORT THE SAME LIST AND RETURNS IT.

# %%
newl
# Out:
# [2, 3, 4, 5, 7, 8, 67]

# %%
copy(newl)
# Out:
# The system cannot find the file specified.

# %%
l1 = [4, 3, 2, False, 4,[4, 7, 5]]

# %%
l1[5][0]
# Out:
# 4

# %%
list1 = [2,3,4]
list2 = [6,6,7]

# %%
list1 + list2 #RETUENS NEW LIST
# Out:
# [2, 3, 4, 6, 6, 7]

# %%
list1
# Out:
# [2, 3, 4]

# %%
list2
# Out:
# [6, 6, 7]

# %%
if 6 in list2:
    print("Yes")
# Out:
# Yes

# %%
3 in list1 #MEMBERSHIP
# Out:
# True

# %%
32 in list1
# Out:
# False

# %%
str = "mihir-krunal-ali-javed-meet-sahil-het"

# %%
str.split("-")
# Out:
# ['mihir', 'krunal', 'ali', 'javed', 'meet', 'sahil', 'het']
