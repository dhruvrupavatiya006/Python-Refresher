# %%
23/32*3-4**5
# Out:
# -1021.84375

# %%
4**5
# Out:
# 1024

# %%
23/32*3-1024
# Out:
# -1021.84375

# %%
#Exponential goes right to left(HIGHEST PRECEDENCE)

#Example : 2**3**5 = 2**(3**5) = ....

# %%
#Multiplication and Division goes left to right...(LOWER PRECEDENCE THAN **)

#Example = 2*3*5 = (2*3)*5 = ....
#EX : 16 / 4 * 2 = (16/4)*2 = ...
