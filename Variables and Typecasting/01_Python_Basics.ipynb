# %%
a=30

# %%
b=30

# %%
a+b
# Out:
# 60

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = "HEllo"

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
#This is a single line comment

# %%
type(a)
# Out:
# str

# %%
a = "3434"
b = "3242"

# %%
print(a+b)
# Out:
# 34343242

# %%
int(a) + int (b) #Typecasting
# Out:
# 6676
