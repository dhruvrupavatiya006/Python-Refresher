# %%
name = "Dhruv"

# %%
name
# Out:
# 'Dhruv'

# %%
name.upper()
# Out:
# 'DHRUV'

# %%
name.endswith('uv')
# Out:
# True

# %%
name.endswith('dsds')
# Out:
# False

# %%
name.lower()
# Out:
# 'dhruv'

# %%
name.count('a')
# Out:
# 0

# %%
name.count('D')
# Out:
# 1

# %%
text = "  hello  "
text.strip()
# Out:
# 'hello'

# %%
text[0:5]
# Out:
# '  hel'

# %%
name[1:-1]
# Out:
# 'hru'

# %%
name[-4:-1]
# Out:
# 'hru'
