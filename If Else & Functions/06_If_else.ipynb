# %%
a = 400

# %%
if(a>53):
    print("Greater")
else:
    print("Smaller")
# Out:
# Greater

# %%
b = 40
if b>50:
    print("Greater than 50")
elif(b>30):
    print("Greater than 30")
elif(b>20):
    print("Greater than 20")
else:
    print("NO")
# Out:
# Greater than 30

# %% [markdown]
# # Functions in python

# %%
def avg(a, b):
    return (a+b)/2

# %%
avg(4, 6)
# Out:
# 5.0

# %%
avg(0, 1)
# Out:
# 0.5

# %%
avg(2, 2)
# Out:
# 2.0

# %%
def avgs(c, d=20): #Default Arguments
    return (c+d)/2

# %%
avgs(20)
# Out:
# 20.0

# %%
def greet():
    print("Hello good morning")

# %%
greet()
# Out:
# Hello good morning

# %%
#NONE is a object in python

# %%
None
