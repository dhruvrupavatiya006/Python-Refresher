# %%
#Makes If Else littel Easier for some cases

# %%
code = 5000

# %%
match code:
    case 200:
        print("Response OK")
        print("Good Job!!")
    case 400:
        print("Bad Response")
    case 404:
        print("Not Found")
    case _:
        print("Nothing Matched")
print("End of program")
# Out:
# Nothing Matched
# End of program
